# %% [markdown]
# # Exercise 2: Splitter and merger
#
# <img src='https://naavre.net/img/hero-light.svg' width=200 align=right>
#
# In this exercise, we learn how to use the splitter and merger. This is useful to process data in parallel with the workflow.
#
# We start with the tutorial workflow ([Your first workflow in Python.ipynb](./Your%20first%20workflow%20in%20Python.ipynb)), and modify it to add the merger. The cells are copied in this notebook, so that you can modify them directly.

# %%
# ex2 1: input list
names = ["Alice", "Bob"]

# %% [markdown]
# _Step 1_
#
# Modify cell 2 to create a variable `sentences`, instead of printing the message:
#
# ```python
# sentences = []
# for name in names:
#     sentences.append(f"Hello, {name}!")
# ```

# %%
# ex2 2: process list
for name in names:
    print(f"Hello, {name}!")

# %% [markdown]
# _Step 2_
#
# Create a 3rd cell (`# ex2 3: print list`) which prints the variable `sentences`.

# %% [markdown]
# _Step 3_
#
# Containerize the cells

# %% [markdown]
# _Step 4_
#
# Create a workflow.
#
# ![Workflow with a splitter before cell 2 and a merger after](attachment:101c563e-12d0-4e26-9c20-1cfbc5b8aba9.png)
