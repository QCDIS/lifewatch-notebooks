# %%
import fnmatch
import json
import getpass
import os
import pathlib
import datetime
import laspy
                    
from dask.distributed import LocalCluster, SSHCluster 
from laserfarm import Retiler, DataProcessing, GeotiffWriter, MacroPipeline
from laserfarm.remote_utils import get_wdclient, get_info_remote, list_remote

# %% [markdown]
# ## Global Configuration

# %%
# Configurations spiros

import fnmatch
import json
import getpass
import os
import pathlib
import datetime
                    
from dask.distributed import LocalCluster, SSHCluster 
from laserfarm import Retiler, DataProcessing, GeotiffWriter, MacroPipeline
from laserfarm.remote_utils import get_wdclient, get_info_remote, list_remote

conf_remote_path_root = pathlib.Path('/webdav')
conf_remote_path_ahn = pathlib.Path('/webdav/ahn')
conf_remote_path_retiled = pathlib.Path('/webdav/retiled/')
conf_remote_path_norm = pathlib.Path('/webdav/norm/')
conf_remote_path_targets = pathlib.Path('/webdav/targets')
conf_local_tmp = pathlib.Path('/tmp')

param_hostname = ''
param_login = ''
param_password = ''

param_feature_name = 'perc_95_normalized_height'
param_validate_precision = '0.00001'
param_tile_mesh_size = '10.'
param_filter_type= 'select_equal'
param_attribute = 'raw_classification'
param_min_x = '-113107.81'
param_max_x = '398892.19'
param_min_y = '214783.87'
param_max_y = '726783.87'
param_n_tiles_side = '512'
param_apply_filter_value = '1'
param_laz_compression_factor = '7'

conf_wd_opts = { 'webdav_hostname': param_hostname, 'webdav_login': param_login, 'webdav_password': param_password}

# %% [markdown]
# ## Fetching Laz Files from remote WebDAV

# %%
# Fetch Laz Files 08-04-22
laz_files = [f for f in list_remote(get_wdclient(conf_wd_opts), conf_remote_path_ahn.as_posix())
             if f.lower().endswith('.laz')]

# %% [markdown]
# ## Splitting big files into smaller files before retiling
# This step can be added if the original files are too large for normal VMs to process

# %%
# split big files 

max_filesize = 250 * 2**20  # desired max file size (in bytes)
def save_chunk_to_laz_file(in_filename, 
                           out_filename, 
                           offset, 
                           n_points):
    """Read points from a LAS/LAZ file and write them to a new file."""
    
    points = np.array([])
    
    with laspy.open(in_filename) as in_file:
        with laspy.open(out_filename, 
                        mode="w", 
                        header=in_file.header) as out_file:
            in_file.seek(offset)
            points = in_file.read_points(n_points)
            out_file.write_points(points)
    return len(points)

def split_strategy(filename, max_filesize):
    """Set up splitting strategy for a LAS/LAZ file."""
    with laspy.open(filename) as f:
        bytes_per_point = (
            f.header.point_format.num_standard_bytes +
            f.header.point_format.num_extra_bytes
        )
        n_points = f.header.point_count
    n_points_target = int(
        max_filesize * int(param_laz_compression_factor) / bytes_per_point
    )
    stem, ext = os.path.splitext(filename)
    return [
        (filename, f"{stem}-{n}{ext}", offset, n_points_target)
        for n, offset in enumerate(range(0, n_points, n_points_target))
    ]

##################### Don't know how to run this sequentially ################################
# for file in files:
#     split_strategy(file,max_filesize)

# %% [markdown]
# ## Retiling of big files into smaller tiles

# %%
# Retiling 08-04-22


from IPython.display import display, HTML   

remote_path_retiled = str(conf_remote_path_retiled)

grid_retile = {
    'min_x': float(param_min_x),
    'max_x': float(param_max_x),
    'min_y': float(param_min_y),
    'max_y': float(param_max_y),
    'n_tiles_side': int(param_n_tiles_side)
}


retiling_input = {
    'setup_local_fs': {'tmp_folder': conf_local_tmp.as_posix()},
    'pullremote': conf_remote_path_ahn.as_posix(),
    'set_grid': grid_retile,
    'split_and_redistribute': {},
    'validate': {},
    'pushremote': conf_remote_path_retiled.as_posix(),
    'cleanlocalfs': {}
}


# try:
#     get_ipython
#     file = laz_files[0]
# except:
#     file = laz_files
    
for file in laz_files:
    retiler = Retiler(file,label=file).config(retiling_input).setup_webdav_client(conf_wd_opts)
    retiler_output = retiler.run()
# Out:
# 2022-05-22 12:40:24,587 -           laserfarm.pipeline_remote_data -       INFO - Input dir set to /tmp/C_18HZ2.LAZ_input
# 2022-05-22 12:40:24,588 -           laserfarm.pipeline_remote_data -       INFO - Output dir set to /tmp/C_18HZ2.LAZ_output
# 2022-05-22 12:40:24,590 -           laserfarm.pipeline_remote_data -       INFO - Pulling from WebDAV /webdav/ahn/C_18HZ2.LAZ ...
# 2022-05-22 12:40:26,182 -           laserfarm.pipeline_remote_data -       INFO - ... pulling completed.
# 2022-05-22 12:40:26,183 -                        laserfarm.retiler -       INFO - Setting up the target grid
# 2022-05-22 12:40:26,188 -                        laserfarm.retiler -       INFO - Splitting file /tmp/C_18HZ2.LAZ_input/C_18HZ2.LAZ with PDAL ...
# 2022-05-22 12:40:26,587 -                        laserfarm.retiler -       INFO - ... splitting completed.
# 2022-05-22 12:40:26,590 -                        laserfarm.retiler -       INFO - Redistributing files to tiles ...
# 2022-05-22 12:40:26,594 -                        laserfarm.retiler -       INFO - ... file C_18HZ2_1.LAZ to tile_213_285
# 2022-05-22 12:40:26,596 -                        laserfarm.retiler -       INFO - ... file C_18HZ2_2.LAZ to tile_212_285
# 2022-05-22 12:40:26,597 -                        laserfarm.retiler -       INFO - ... redistributing completed.
# 2022-05-22 12:40:26,599 -                        laserfarm.retiler -       INFO - Validating split ...
# 2022-05-22 12:40:26,601 -                        laserfarm.retiler -       INFO - ... 257128 points in parent file
# 2022-05-22 12:40:26,605 -                        laserfarm.retiler -       INFO - ... 25414 points in C_18HZ2_2.LAZ
# 2022-05-22 12:40:26,606 -                        laserfarm.retiler -       INFO - ... 231714 points in C_18HZ2_1.LAZ
# 2022-05-22 12:40:26,609 -                        laserfarm.retiler -       INFO - ... split validation completed.
# 2022-05-22 12:40:26,611 -           laserfarm.pipeline_remote_data -       INFO - Pushing to WebDAV /webdav/retiled ...
# 2022-05-22 12:40:33,664 -           laserfarm.pipeline_remote_data -       INFO - ... pushing completed.
# 2022-05-22 12:40:33,668 -           laserfarm.pipeline_remote_data -       INFO - Removing input and output folders
# 2022-05-22 12:40:33,673 -           laserfarm.pipeline_remote_data -       INFO - Input dir set to /tmp/C_19HZ2.LAZ_input
# 2022-05-22 12:40:33,675 -           laserfarm.pipeline_remote_data -       INFO - Output dir set to /tmp/C_19HZ2.LAZ_output
# 2022-05-22 12:40:33,678 -           laserfarm.pipeline_remote_data -       INFO - Pulling from WebDAV /webdav/ahn/C_19HZ2.LAZ ...
# 2022-05-22 12:40:35,206 -           laserfarm.pipeline_remote_data -       INFO - ... pulling completed.
# 2022-05-22 12:40:35,209 -                        laserfarm.retiler -       INFO - Setting up the target grid
# 2022-05-22 12:40:35,211 -                        laserfarm.retiler -       INFO - Splitting file /tmp/C_19HZ2.LAZ_input/C_19HZ2.LAZ with PDAL ...
# 2022-05-22 12:40:35,336 -                        laserfarm.retiler -       INFO - ... splitting completed.
# 2022-05-22 12:40:35,340 -                        laserfarm.retiler -       INFO - Redistributing files to tiles ...
# 2022-05-22 12:40:35,343 -                        laserfarm.retiler -       INFO - ... file C_19HZ2_1.LAZ to tile_248_285
# 2022-05-22 12:40:35,344 -                        laserfarm.retiler -       INFO - ... redistributing completed.
# 2022-05-22 12:40:35,347 -                        laserfarm.retiler -       INFO - Validating split ...
# 2022-05-22 12:40:35,348 -                        laserfarm.retiler -       INFO - ... 66663 points in parent file
# 2022-05-22 12:40:35,351 -                        laserfarm.retiler -       INFO - ... 66663 points in C_19HZ2_1.LAZ
# 2022-05-22 12:40:35,352 -                        laserfarm.retiler -       INFO - ... split validation completed.
# 2022-05-22 12:40:35,355 -           laserfarm.pipeline_remote_data -       INFO - Pushing to WebDAV /webdav/retiled ...
# 2022-05-22 12:40:40,485 -           laserfarm.pipeline_remote_data -       INFO - ... pushing completed.
# 2022-05-22 12:40:40,488 -           laserfarm.pipeline_remote_data -       INFO - Removing input and output folders
# 2022-05-22 12:40:40,493 -           laserfarm.pipeline_remote_data -       INFO - Input dir set to /tmp/C_50GZ2.LAZ_input
# 2022-05-22 12:40:40,495 -           laserfarm.pipeline_remote_data -       INFO - Output dir set to /tmp/C_50GZ2.LAZ_output
# 2022-05-22 12:40:40,498 -           laserfarm.pipeline_remote_data -       INFO - Pulling from WebDAV /webdav/ahn/C_50GZ2.LAZ ...
# 2022-05-22 12:40:42,360 -           laserfarm.pipeline_remote_data -       INFO - ... pulling completed.
# 2022-05-22 12:40:42,361 -                        laserfarm.retiler -       INFO - Setting up the target grid
# 2022-05-22 12:40:42,365 -                        laserfarm.retiler -       INFO - Splitting file /tmp/C_50GZ2.LAZ_input/C_50GZ2.LAZ with PDAL ...
# 2022-05-22 12:40:43,201 -                        laserfarm.retiler -       INFO - ... splitting completed.
# 2022-05-22 12:40:43,202 -                        laserfarm.retiler -       INFO - Redistributing files to tiles ...
# 2022-05-22 12:40:43,204 -                        laserfarm.retiler -       INFO - ... file C_50GZ2_1.LAZ to tile_238_166
# 2022-05-22 12:40:43,205 -                        laserfarm.retiler -       INFO - ... redistributing completed.
# 2022-05-22 12:40:43,205 -                        laserfarm.retiler -       INFO - Validating split ...
# 2022-05-22 12:40:43,206 -                        laserfarm.retiler -       INFO - ... 499572 points in parent file
# 2022-05-22 12:40:43,212 -                        laserfarm.retiler -       INFO - ... 499572 points in C_50GZ2_1.LAZ
# 2022-05-22 12:40:43,213 -                        laserfarm.retiler -       INFO - ... split validation completed.
# 2022-05-22 12:40:43,214 -           laserfarm.pipeline_remote_data -       INFO - Pushing to WebDAV /webdav/retiled ...
# 2022-05-22 12:40:48,544 -           laserfarm.pipeline_remote_data -       INFO - ... pushing completed.
# 2022-05-22 12:40:48,545 -           laserfarm.pipeline_remote_data -       INFO - Removing input and output folders

# %% [markdown]
# ## Fetching retilied files (tiles) from remote WebDAV

# %%
# Fetch Tiles 08-04-22
remote_path_retiled
tiles = [t.strip('/') for t in list_remote(get_wdclient(conf_wd_opts), conf_remote_path_retiled.as_posix())
         if fnmatch.fnmatch(t, 'tile_*_*/')]

# %% [markdown]
# ## Normalization - normalize all the point cloud

# %% [markdown]
# This step is added as the previous notebook did not include this step. The two cells below are the original code deployed on SURF using macroPipline function, so it needs to be modified in order to be containerized.

# %%
# setup input dictionary to configure the normalization pipeline
import copy

tiles

remote_path_norm = str(conf_remote_path_norm)

normalization_input = {
    'setup_local_fs': {'tmp_folder': conf_local_tmp.as_posix()},
    'pullremote': conf_remote_path_retiled.as_posix(),
    'load': {'attributes': 'all'},
    # Filter out artifically high points - give overflow error when writing
    'apply_filter': {'filter_type':'select_below',
                     'attribute': 'z',
                     'threshold': 10000.},  # remove non-physically heigh points
    'normalize': 1,
    'clear_cache' : {},
    'pushremote': conf_remote_path_norm.as_posix(),
}

# write input dictionary to JSON file
with open('normalize.json', 'w') as f:
-           laserfarm.pipeline_remote_data -       INFO - ... pushing completed.
# 2022-05-22 12:53:30,748 -           laserfarm.pipeline_remote_data -       INFO - Input dir set to /tmp/tile_258_385_input
# 2022-05-22 12:53:30,749 -           laserfarm.pipeline_remote_data -       INFO - Output dir set to /tmp/tile_258_385_output
# 2022-05-22 12:53:30,753 -           laserfarm.pipeline_remote_data -       INFO - Pulling from WebDAV /webdav/retiled/tile_258_385 ...
# 2022-05-22 12:53:34,294 -           laserfarm.pipeline_remote_data -       INFO - ... pulling completed.
# 2022-05-22 12:53:34,296 -                laserfarm.data_processing -       INFO - Loading point cloud data ...
# 2022-05-22 12:53:34,296 -                laserfarm.data_processing -       INFO - ... loading /tmp/tile_258_385_input/tile_258_385/C_01CZ1_10.LAZ
# 2022-05-22 12:53:35,366 -                laserfarm.data_processing -       INFO - ... loading completed.
# 2022-05-22 12:53:35,371 -                laserfarm.data_processing -       INFO - Normalizing point-cloud heights ...
# 2022-05-22 12:53:35,534 -                                     root -       INFO - Cylinder size in Bytes: 542650063.6561003
# 2022-05-22 12:53:35,541 -                                     root -       INFO - Memory size in Bytes: 7113195520
# 2022-05-22 12:53:35,541 -                                     root -       INFO - Start tree creation
# 2022-05-22 12:53:35,777 -                                     root -       INFO - Done with env tree creation
# 2022-05-22 12:53:35,789 -                                     root -       INFO - Done with target tree creation
# 2022-05-22 12:53:43,173 -                laserfarm.data_processing -       INFO - ... normalization completed.
# 2022-05-22 12:53:43,176 -                laserfarm.data_processing -       INFO - Filtering point-cloud data
# 2022-05-22 12:53:43,208 -                laserfarm.data_processing -       INFO - Exporting environment point-cloud ...
# 2022-05-22 12:53:43,211 -                laserfarm.data_processing -       INFO - ... exporting /tmp/tile_258_385_output/tile_258_385.laz
# 2022-05-22 12:53:44,509 -                laserfarm.data_processing -       INFO - ... exporting completed.
# 2022-05-22 12:53:44,515 -                laserfarm.data_processing -       INFO - Clearing cached KDTrees ...
# 2022-05-22 12:53:44,517 -           laserfarm.pipeline_remote_data -       INFO - Pushing to WebDAV /webdav/norm ...
# 2022-05-22 12:53:49,297 -           laserfarm.pipeline_remote_data -       INFO - ... pushing completed.
# 2022-05-22 12:53:49,304 -           laserfarm.pipeline_remote_data -       INFO - Input dir set to /tmp/tile_288_379_input
# 2022-05-22 12:53:49,308 -           laserfarm.pipeline_remote_data -       INFO - Output dir set to /tmp/tile_288_379_output
# 2022-05-22 12:53:49,315 -           laserfarm.pipeline_remote_data -       INFO - Pulling from WebDAV /webdav/retiled/tile_288_379 ...
# 2022-05-22 12:53:51,942 -           laserfarm.pipeline_remote_data -       INFO - ... pulling completed.
# 2022-05-22 12:53:51,945 -                laserfarm.data_processing -       INFO - Loading point cloud data ...
# 2022-05-22 12:53:51,947 -                laserfarm.data_processing -       INFO - ... loading /tmp/tile_288_379_input/tile_288_379/C_05FN1_4.LAZ
# 2022-05-22 12:53:52,088 -                laserfarm.data_processing -       INFO - ... loading completed.
# 2022-05-22 12:53:52,091 -                laserfarm.data_processing -       INFO - Normalizing point-cloud heights ...
# 2022-05-22 12:53:52,133 -                                     root -       INFO - Cylinder size in Bytes: 115590000.80429688
# 2022-05-22 12:53:52,139 -                                     root -       INFO - Memory size in Bytes: 7113195520
# 2022-05-22 12:53:52,141 -                                     root -       INFO - Start tree creation
# 2022-05-22 12:53:52,177 -                                     root -       INFO - Done with env tree creation
# 2022-05-22 12:53:52,183 -                                     root -       INFO - Done with target tree creation
# 2022-05-22 12:53:53,345 -                laserfarm.data_processing -       INFO - ... normalization completed.
# 2022-05-22 12:53:53,351 -                laserfarm.data_processing -       INFO - Filtering point-cloud data
# 2022-05-22 12:53:53,356 -                laserfarm.data_processing -       INFO - Exporting environment point-cloud ...
# 2022-05-22 12:53:53,357 -                laserfarm.data_processing -       INFO - ... exporting /tmp/tile_288_379_output/tile_288_379.laz
# 2022-05-22 12:53:53,513 -                laserfarm.data_processing -       INFO - ... exporting completed.
# 2022-05-22 12:53:53,515 -                laserfarm.data_processing -       INFO - Clearing cached KDTrees ...
# 2022-05-22 12:53:53,516 -           laserfarm.pipeline_remote_data -       INFO - Pushing to WebDAV /webdav/norm ...
# 2022-05-22 12:53:56,266 -           laserfarm.pipeline_remote_data -       INFO - ... pushing completed.
# 2022-05-22 12:53:56,270 -           laserfarm.pipeline_remote_data -       INFO - Input dir set to /tmp/tile_258_387_input
# 2022-05-22 12:53:56,271 -           laserfarm.pipeline_remote_data -       INFO - Output dir set to /tmp/tile_258_387_output
# 2022-05-22 12:53:56,275 -           laserfarm.pipeline_remote_data -       INFO - Pulling from WebDAV /webdav/retiled/tile_258_387 ...
# 2022-05-22 12:53:58,945 -           laserfarm.pipeline_remote_data -       INFO - ... pulling completed.
# 2022-05-22 12:53:58,946 -                laserfarm.data_processing -       INFO - Loading point cloud data ...
# 2022-05-22 12:53:58,946 -                laserfarm.data_processing -       INFO - ... loading /tmp/tile_258_387_input/tile_258_387/C_01CZ1_12.LAZ
# 2022-05-22 12:53:58,994 -                laserfarm.data_processing -       INFO - ... loading completed.
# 2022-05-22 12:53:58,995 -                laserfarm.data_processing -       INFO - Normalizing point-cloud heights ...
# 2022-05-22 12:53:59,051 -                                     root -       INFO - Cylinder size in Bytes: 129433114.67307493
# 2022-05-22 12:53:59,052 -                                     root -       INFO - Memory size in Bytes: 7113195520
# 2022-05-22 12:53:59,053 -                                     root -       INFO - Start tree creation
# 2022-05-22 12:53:59,066 -                                     root -       INFO - Done with env tree creation
# 2022-05-22 12:53:59,071 -                                     root -       INFO - Done with target tree creation
# 2022-05-22 12:53:59,973 -                laserfarm.data_processing -       INFO - ... normalization completed.
# 2022-05-22 12:53:59,979 -                laserfarm.data_processing -       INFO - Filtering point-cloud data
# 2022-05-22 12:53:59,981 -                laserfarm.data_processing -       INFO - Exporting environment point-cloud ...
# 2022-05-22 12:53:59,982 -                laserfarm.data_processing -       INFO - ... exporting /tmp/tile_258_387_output/tile_258_387.laz
# 2022-05-22 12:54:00,070 -                laserfarm.data_processing -       INFO - ... exporting completed.
# 2022-05-22 12:54:00,073 -                laserfarm.data_processing -       INFO - Clearing cached KDTrees ...
# 2022-05-22 12:54:00,080 -           laserfarm.pipeline_remote_data -       INFO - Pushing to WebDAV /webdav/norm ...
# 2022-05-22 12:54:02,856 -           laserfarm.pipeline_remote_data -       INFO - ... pushing completed.
# 2022-05-22 12:54:02,862 -           laserfarm.pipeline_remote_data -       INFO - Input dir set to /tmp/tile_278_392_input
# 2022-05-22 12:54:02,864 -           laserfarm.pipeline_remote_data -       INFO - Output dir set to /tmp/tile_278_392_output
# 2022-05-22 12:54:02,871 -           laserfarm.pipeline_remote_data -       INFO - Pulling from WebDAV /webdav/retiled/tile_278_392 ...
# 2022-05-22 12:54:05,496 -           laserfarm.pipeline_remote_data -       INFO - ... pulling completed.
# 2022-05-22 12:54:05,500 -                laserfarm.data_processing -       INFO - Loading point cloud data ...
# 2022-05-22 12:54:05,502 -                laserfarm.data_processing -       INFO - ... loading /tmp/tile_278_392_input/tile_278_392/C_01GN2_2.LAZ
# 2022-05-22 12:54:05,533 -                laserfarm.data_processing -       INFO - ... loading completed.
# 2022-05-22 12:54:05,536 -                laserfarm.data_processing -       INFO - Normalizing point-cloud heights ...
# 2022-05-22 12:54:05,562 -                                     root -       INFO - Cylinder size in Bytes: 71151041.74591394
# 2022-05-22 12:54:05,563 -                                     root -       INFO - Memory size in Bytes: 7113195520
# 2022-05-22 12:54:05,565 -                                     root -       INFO - Start tree creation
# 2022-05-22 12:54:05,571 -                                     root -       INFO - Done with env tree creation
# 2022-05-22 12:54:05,574 -                                     root -       INFO - Done with target tree creation
# 2022-05-22 12:54:06,017 -                laserfarm.data_processing -       INFO - ... normalization completed.
# 2022-05-22 12:54:06,023 -                laserfarm.data_processing -       INFO - Filtering point-cloud data
# 2022-05-22 12:54:06,027 -                laserfarm.data_processing -       INFO - Exporting environment point-cloud ...
# 2022-05-22 12:54:06,034 -                laserfarm.data_processing -       INFO - ... exporting /tmp/tile_278_392_output/tile_278_392.laz
# 2022-05-22 12:54:06,076 -                laserfarm.data_processing -       INFO - ... exporting completed.
# 2022-05-22 12:54:06,079 -                laserfarm.data_processing -       INFO - Clearing cached KDTrees ...
# 2022-05-22 12:54:06,081 -           laserfarm.pipeline_remote_data -       INFO - Pushing to WebDAV /webdav/norm ...
# 2022-05-22 12:54:08,642 -           laserfarm.pipeline_remote_data -       INFO - ... pushing completed.

# %% [markdown]
# ## Fetching normalized files (tiles) from remote WebDAV

# %%
# Fetch norm Tiles 
remote_path_norm
norm_tiles = [t.strip('/') for t in list_remote(get_wdclient(conf_wd_opts), conf_remote_path_norm.as_posix())
         if fnmatch.fnmatch(t, 'tile_*_*.laz')]

# %% [markdown]
# ## Extract features - extract defined features from normalized tiles

# %%
# Feature Extraction 08-04-22

features = [param_feature_name]

tile_mesh_size = float(param_tile_mesh_size)

grid_feature = {
    'min_x': float(param_min_x),
    'max_x': float(param_max_x),
    'min_y': float(param_min_y),
    'max_y': float(param_max_y),
    'n_tiles_side': int(param_n_tiles_side)
}

feature_extraction_input = {
    'setup_local_fs': {'tmp_folder': conf_local_tmp.as_posix()},
    'pullremote': conf_remote_path_norm.as_posix(),
    'load': {'attributes': [param_attribute]},
    'normalize': 1,
    'apply_filter': {
        'filter_type': param_filter_type, 
        'attribute': param_attribute,
        'value': [int(param_apply_filter_value)]#ground surface (2), water (9), buildings (6), artificial objects (26), and unclassified (1)
    },
    'generate_targets': {
        'tile_mesh_size' : tile_mesh_size,
        'validate' : True,
        'validate_precision': float(param_validate_precision),
        **grid_feature
    },
    'extract_features': {
        'feature_names': features,
        'volume_type': 'cell',
        'volume_size': tile_mesh_size
    },
    'export_targets': {
        'attributes': features,
        'multi_band_files': False
    },
    'pushremote': conf_remote_path_targets.as_posix(),
#     'cleanlocalfs': {}
}    
    
for t in norm_tiles:
    idx = (t.split('_')[1:])
    processing = DataProcessing(t, tile_index=idx,label=t).config(feature_extraction_input).setup_webdav_client(conf_wd_opts)
    processing.run()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 44>()
#      45 idx = (t.split('_')[1:])
#      46 processing = DataProcessing(t, tile_index=idx,label=t).config(feature_extraction_input).setup_webdav_client(conf_wd_opts)
# ---> 47 processing.run()
#
# File /opt/conda/lib/python3.9/site-packages/laserfarm/pipeline_remote_data.py:113, in PipelineRemoteData.run(self, pipeline)
#     109 _pipeline = pipeline if pipeline is not None else self.pipeline
#     110 _pipeline = (('setup_local_fs', 'setup_webdav_client', 'pullremote')
#     111              + _pipeline
#     112              + ('pushremote', 'cleanlocalfs'))
# --> 113 super(PipelineRemoteData, self).run(pipeline=_pipeline)
#
# File /opt/conda/lib/python3.9/site-packages/laserfarm/pipeline.py:108, in Pipeline.run(self, pipeline)
#     106 input_task = _input.pop(task_name)
#     107 if isinstance(input_task, dict):
# --> 108     task(**input_task)
#     109 elif (isinstance(input_task, list)
#     110       or isinstance(input_task, tuple)):
#     111     task(*input_task)
#
# File /opt/conda/lib/python3.9/site-packages/laserfarm/data_processing.py:189, in DataProcessing.generate_targets(self, min_x, min_y, max_x, max_y, n_tiles_side, tile_mesh_size, validate, validate_precision)
#     186     logger.info('Checking whether points belong to cell '
#     187                 '({},{})'.format(*self._tile_index))
#     188     x_all, y_all, _ = get_point(self.point_cloud, ...)
# --> 189     mask = self.grid.is_point_in_tile(x_all,
#     190                                       y_all,
#     191                                       self._tile_index[0],
#     192                                       self._tile_index[1],
#     193                                       validate_precision)
#     194     assert np.all(mask), ('{} points belong to (a) different tile(s)'
#     195                           '!'.format(len(x_all[~mask])))
#     197 logger.info('Generating target point mesh with '
#     198             '{}m spacing '.format(tile_mesh_size))
#
# File /opt/conda/lib/python3.9/site-packages/laserfarm/grid.py:126, in Grid.is_point_in_tile(self, px, py, tile_index_x, tile_index_y, precision)
#     124 else:
#     125     point_cart = np.array([px, py], dtype=np.float).T
# --> 126     tile_mins, tile_maxs = self.get_tile_bounds(tile_index_x,
#     127                                                 tile_index_y)
#     128     mask = np.logical_and(tile_mins - point_cart <= precision,
#     129                           point_cart - tile_maxs <= precision)
#     130 return np.all(mask, axis=1)
#
# File /opt/conda/lib/python3.9/site-packages/laserfarm/grid.py:103, in Grid.get_tile_bounds(self, tile_index_x, tile_index_y)
#      96 def get_tile_bounds(self, tile_index_x, tile_index_y):
#      97     """
#      98     Determine the boundaries of a tile given its X and Y indices.
#      99
#     100     :param tile_index_x: Tile index along X
#     101     :param tile_index_y: Tile index along Y
#     102     """
# --> 103     tile_index = np.array([tile_index_x, tile_index_y], dtype=np.int)
#     104     tile_mins = tile_index * self.tile_width + self.grid_mins
#     105     tile_maxs = tile_mins + self.tile_width
#
# ValueError: invalid literal for int() with base 10: '378.laz'

# %% [markdown]
# ## GeoTIFF export - generate GeoTIFF raster layer a

# %%
# GeoTIFF Export 08-04-22

feature = features

remote_path_geotiffs = conf_remote_path_ahn.parent / 'geotiffs'

# setup input dictionary to configure the GeoTIFF export pipeline
geotiff_export_input = {
    'setup_local_fs': {'tmp_folder': conf_local_tmp.as_posix()},
    'pullremote': conf_remote_path_targets.as_posix(),
    'parse_point_cloud': {},
    'data_split': {'xSub': 1, 'ySub': 1},
    'create_subregion_geotiffs': {'output_handle': 'geotiff'},
    'pushremote': remote_path_geotiffs.as_posix(),
    'cleanlocalfs': {}   
}

writer = GeotiffWriter(input_dir=param_feature_name, bands=param_feature_name,label=param_feature_name).config(geotiff_export_input).setup_webdav_client(conf_wd_opts)
writer.run()

# %%
print(remote_path_geotiffs)
